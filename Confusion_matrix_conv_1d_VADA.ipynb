# %%
import os
import sys
import argparse
from codebase import args as codebase_args
from pprint import pprint
import tensorflow as tf
from codebase.utils import get_data
from codebase.utils import exact_accuracy
import numpy as np
from glob import glob
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pandas as pd
import matplotlib as plt
from more_itertools import chunked

# %%
def build_model(src, trg, design, trim):
    parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument('--src',    type=str,   default='stl', help="Src data")
    parser.add_argument('--trg',    type=str,   default='cifar',    help="Trg data")
    parser.add_argument('--design', type=str,   default='v17_y_nin',     help="design")
    parser.add_argument('--trim',   type=int,   default=5,         help="Trim")
    parser.add_argument('--pert',   type=str,   default='vat',     help="Type of perturbation")
    parser.add_argument('--ball',   type=float, default=3.5,       help="Ball weight")
    parser.add_argument('--cw',     type=float, default=0,      help="Conditional entropy weight")
    parser.add_argument('--dw',     type=float, default=0,      help="Domain weight")
    parser.add_argument('--gw',     type=float, default=0.0,       help="Gen weight")
    parser.add_argument('--y-emp',  type=int,   default=0,         help="Whether to use empirical y")
    parser.add_argument('--te',     type=float, default=0,         help="Trg embedding ball weight")
    parser.add_argument('--se',     type=float, default=0,         help="Src embedding ball weight")
    parser.add_argument('--tbw',    type=float, default=0,      help="Trg ball weight")
    parser.add_argument('--gbw',    type=float, default=0.0,       help="Fake ball weight")
    parser.add_argument('--sbw',    type=float, default=0,         help="Src ball weight")
    parser.add_argument('--lr',     type=float, default=1e-3,      help="Learning rate")
    parser.add_argument('--dirt',   type=int,   default=50000,         help="Flag for DIRT algorithm")
    parser.add_argument('--init',   type=int,   default=0,         help="Flag for re-init")
    parser.add_argument('--pivot',  type=int,   default=90000,     help="Pivot iteration for up/dn/dwdn")
    parser.add_argument('--uval',   type=float, default=0,         help="Up value")
    parser.add_argument('--dcval',  type=float, default=0,         help="Down value. Does not apply to SBW!")
    parser.add_argument('--up',     type=int,   default=0,         help="Ramping up flag")
    parser.add_argument('--dn',     type=int,   default=0,         help="Ramping down flag")
    parser.add_argument('--dwdn',   type=int,   default=0,         help="Ramping down dw flag")
    parser.add_argument('--phase',  type=int,   default=0,         help="Init phase v. DIRT phase")
    parser.add_argument('--run',    type=int,   default=999,       help="Run index")
    codebase_args.args = args = parser.parse_args([])

    args.src = src
    args.trg = trg
    args.design = design 
    args.trim = trim
    
    from codebase.models.dann_embed import dann_embed

    tf.reset_default_graph()
    M = dann_embed()
    M.sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
#    trg = get_data(args.trg)
    
    return M, saver, trg

def get_confusion_matrix(M, saver, data, restoration_names, iteration=80000):
    x_chunked = list(chunked(data.images,500))
    y_chunked = list(chunked(data.labels,500))
    print(restoration_names)
    path = os.path.join('checkpoints', restoration_names[0], 'model-{:05d}'.format(iteration))

    
    for i in range(len(x_chunked)):
        x_data, y_data = x_chunked[i], y_chunked[i]
        if i == 0:
            y_true = np.argmax(y_data,1)
        else:
            y_true = np.append(y_true, np.argmax(y_data,1))
        try:
            saver.restore(M.sess, path)
            if i == 0:
                y_pred =  M.sess.run(tf.argmax(M.ema_e,1), {M.test_x: x_data})
            else:
                y_pred = np.append(y_pred, M.sess.run(tf.argmax(M.ema_e,1), {M.test_x: x_data}))
        
        except tf.errors.NotFoundError:
            print "NOT FOUND"

    confusion = confusion_matrix(y_true, y_pred)
#    confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
            
    return confusion, y_pred

def get_accuracy(M, saver, data, restoration_names, iteration=80000):
    train_test_list = []
    for rn in restoration_names:
        path = os.path.join('checkpoints', rn, 'model-{:05d}'.format(iteration))

        try:
            saver.restore(M.sess, path)
            test_acc, _ = exact_accuracy(M.fn_ema_acc, 'whatev', data.test, full=True)
            train_acc, _ = exact_accuracy(M.fn_ema_acc, 'whatev', data.train, full=False)    
            train_test_list += [[train_acc, test_acc]]
            print train_test_list[-1]

        except tf.errors.NotFoundError:
            print "NOT FOUND"
            
    return np.array(train_test_list)

# %% [markdown]
# # Evaluation

# %%
src = get_data('wifistanford')
trg = get_data('wifimexico')
# Out:
# Loading WifiStanford
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_01/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_02/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/fall_180220_03/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_01/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_02/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/pickup_180220_03/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/08200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/08400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/08600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/08800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/09000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/09200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/09400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/09600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/09800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/10000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/10200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/10400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/10600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/10800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/11000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/11200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/11400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/11600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/11800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/12000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/12200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/12400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/12600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/12800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/13000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/13200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/13400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/13600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/13800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/14000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/14200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/14400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_01/14600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/08200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/08400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/08600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/08800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/09000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/09200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/09400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/09600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/09800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/10000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/10200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/10400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/10600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/10800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/11000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/11200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/11400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/11600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/11800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/12000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/12200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/12400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/12600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/12800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/13000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/13200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/13400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/13600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/13800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/14000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/14200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/14400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/14600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/14800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/15000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/15200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/15400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/15600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/15800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/16000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_02/16200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/08200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/08400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/08600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/08800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/09000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/09200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/09400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/09600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/09800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/10000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/10200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/10400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/10600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/10800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/11000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/11200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/11400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/11600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/11800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/12000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/12200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/12400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/12600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/12800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/13000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/13200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/13400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/13600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/13800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/14000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/14200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/14400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/run_180220_03/14600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/08200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/08400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/08600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/08800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/09000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/09200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/09400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_01/09600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/08200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_02/08400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/sitdown_180220_03/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_01/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_02/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/standup_180220_03/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/05200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/08000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/08200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/08400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/08600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/08800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/09000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/09200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/09400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/09600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/09800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/10000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/10200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/10400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/10600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/10800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/11000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/11200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/11400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/11600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/11800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/12000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/12200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/12400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/12600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/12800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/13000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/13200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/13400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/13600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/13800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/14000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/14200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/14400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/14600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/14800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_01/15000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/05400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/05600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/05800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/06000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/06200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/06400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/06600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/06800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/07000.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/07200.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/07400.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/07600.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/07800.pkl
# ../Pickle/norm/non_smooth/source/train/Stanford_104_NLOS_window_size=2000_threshold=60_slide_siize=200_W400/walk_180220_02/08000.pkl
# ...
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/07200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/07400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/07600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/07800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/08000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/08200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/08400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/08600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/08800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/09000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/09200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/09400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/09600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/09800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/10000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/10200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/10400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/10600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/10800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/11000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/11200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/11400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1607_13/11600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/06200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/06400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/06600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/06800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/07000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/07200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/07400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/07600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/07800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/08000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/08200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/08400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/08600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/08800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/09000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/09200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/09400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/09600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/09800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/10000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/10200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/10400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/10600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/10800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/11000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_14/11200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/06000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/06200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/06400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/06600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/06800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/07000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/07200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/07400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/07600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/07800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/08000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/08200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/08400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/08600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/08800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/09000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/09200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/09400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/09600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/09800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/10000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/10200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/10400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/10600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/10800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/11000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/11200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/11400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/11600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/11800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/12000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_15/12200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/05400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/05600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/05800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/06000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/06200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/06400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/06600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/06800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/07000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/07200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/07400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/07600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/07800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/08000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/08200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/08400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/08600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/08800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/09000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/09200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/09400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/09600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/09800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/10000.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/10200.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/10400.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/10600.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/10800.pkl
# ../Pickle/norm/non_smooth/target/validation/UABC_L2_LOS_window_size=2000_threshold=60_slide_siize=200_W400/person1/walk_170306_1608_16/11000.pkl
# (' fall=', 39, ' normal=', 302)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Confusion Matrix

# %%
M, saver, _ = build_model('wifistanford', 'wifimexico', 'conv_1d', trim=0)
# Out:
# (0, TensorShape([Dimension(None), Dimension(30), Dimension(400), Dimension(3)]))
# (1, TensorShape([Dimension(None), Dimension(1), Dimension(398), Dimension(64)]))
# (2, TensorShape([Dimension(None), Dimension(1), Dimension(396), Dimension(64)]))
# (3, TensorShape([Dimension(None), Dimension(1), Dimension(394), Dimension(64)]))
# (4, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (5, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (6, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (7, TensorShape([Dimension(None), Dimension(1), Dimension(195), Dimension(64)]))
# (8, TensorShape([Dimension(None), Dimension(1), Dimension(193), Dimension(64)]))
# (9, TensorShape([Dimension(None), Dimension(1), Dimension(191), Dimension(64)]))
# (10, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (11, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (12, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (13, TensorShape([Dimension(None), Dimension(1), Dimension(94), Dimension(64)]))
# (14, TensorShape([Dimension(None), Dimension(1), Dimension(92), Dimension(64)]))
# (15, TensorShape([Dimension(None), Dimension(1), Dimension(90), Dimension(64)]))
# (16, TensorShape([Dimension(None), Dimension(2)]))
# (0, TensorShape([Dimension(None), Dimension(30), Dimension(400), Dimension(3)]))
# (1, TensorShape([Dimension(None), Dimension(1), Dimension(398), Dimension(64)]))
# (2, TensorShape([Dimension(None), Dimension(1), Dimension(396), Dimension(64)]))
# (3, TensorShape([Dimension(None), Dimension(1), Dimension(394), Dimension(64)]))
# (4, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (5, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (6, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (7, TensorShape([Dimension(None), Dimension(1), Dimension(195), Dimension(64)]))
# (8, TensorShape([Dimension(None), Dimension(1), Dimension(193), Dimension(64)]))
# (9, TensorShape([Dimension(None), Dimension(1), Dimension(191), Dimension(64)]))
# (10, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (11, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (12, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (13, TensorShape([Dimension(None), Dimension(1), Dimension(94), Dimension(64)]))
# (14, TensorShape([Dimension(None), Dimension(1), Dimension(92), Dimension(64)]))
# (15, TensorShape([Dimension(None), Dimension(1), Dimension(90), Dimension(64)]))
# (16, TensorShape([Dimension(None), Dimension(2)]))
# (0, TensorShape([Dimension(None), Dimension(30), Dimension(400), Dimension(3)]))
# (1, TensorShape([Dimension(None), Dimension(1), Dimension(398), Dimension(64)]))
# (2, TensorShape([Dimension(None), Dimension(1), Dimension(396), Dimension(64)]))
# (3, TensorShape([Dimension(None), Dimension(1), Dimension(394), Dimension(64)]))
# (4, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (5, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (6, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (7, TensorShape([Dimension(None), Dimension(1), Dimension(195), Dimension(64)]))
# (8, TensorShape([Dimension(None), Dimension(1), Dimension(193), Dimension(64)]))
# (9, TensorShape([Dimension(None), Dimension(1), Dimension(191), Dimension(64)]))
# (10, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (11, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (12, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (13, TensorShape([Dimension(None), Dimension(1), Dimension(94), Dimension(64)]))
# (14, TensorShape([Dimension(None), Dimension(1), Dimension(92), Dimension(64)]))
# (15, TensorShape([Dimension(None), Dimension(1), Dimension(90), Dimension(64)]))
# (16, TensorShape([Dimension(None), Dimension(2)]))
# (0, TensorShape([Dimension(None), Dimension(30), Dimension(400), Dimension(3)]))
# (1, TensorShape([Dimension(None), Dimension(1), Dimension(398), Dimension(64)]))
# (2, TensorShape([Dimension(None), Dimension(1), Dimension(396), Dimension(64)]))
# (3, TensorShape([Dimension(None), Dimension(1), Dimension(394), Dimension(64)]))
# (4, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (5, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (6, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (7, TensorShape([Dimension(None), Dimension(1), Dimension(195), Dimension(64)]))
# (8, TensorShape([Dimension(None), Dimension(1), Dimension(193), Dimension(64)]))
# (9, TensorShape([Dimension(None), Dimension(1), Dimension(191), Dimension(64)]))
# (10, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (11, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (12, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (13, TensorShape([Dimension(None), Dimension(1), Dimension(94), Dimension(64)]))
# (14, TensorShape([Dimension(None), Dimension(1), Dimension(92), Dimension(64)]))
# (15, TensorShape([Dimension(None), Dimension(1), Dimension(90), Dimension(64)]))
# (16, TensorShape([Dimension(None), Dimension(2)]))
# (0, TensorShape([Dimension(None), Dimension(30), Dimension(400), Dimension(3)]))
# (1, TensorShape([Dimension(None), Dimension(1), Dimension(398), Dimension(64)]))
# (2, TensorShape([Dimension(None), Dimension(1), Dimension(396), Dimension(64)]))
# (3, TensorShape([Dimension(None), Dimension(1), Dimension(394), Dimension(64)]))
# (4, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (5, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (6, TensorShape([Dimension(None), Dimension(1), Dimension(197), Dimension(64)]))
# (7, TensorShape([Dimension(None), Dimension(1), Dimension(195), Dimension(64)]))
# (8, TensorShape([Dimension(None), Dimension(1), Dimension(193), Dimension(64)]))
# (9, TensorShape([Dimension(None), Dimension(1), Dimension(191), Dimension(64)]))
# (10, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (11, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (12, TensorShape([Dimension(None), Dimension(1), Dimension(96), Dimension(64)]))
# (13, TensorShape([Dimension(None), Dimension(1), Dimension(94), Dimension(64)]))
# (14, TensorShape([Dimension(None), Dimension(1), Dimension(92), Dimension(64)]))
# (15, TensorShape([Dimension(None), Dimension(1), Dimension(90), Dimension(64)]))
# (16, TensorShape([Dimension(None), Dimension(2)]))

# %% [markdown]
# ## VADA

# %%
query = 'log/*src=wifistanford*trg=wifimexico*design=conv_1d_trim=4*dw=1e-02*sbw=1e+00*dirt=00000*0001'
Iter=80000
restore_names = [os.path.basename(v) for v in np.sort(glob(query))]

# %% [markdown]
# ### Source Train

# %%
conf_mat, _ = get_confusion_matrix(M, saver, src.train, restore_names, iteration=Iter)
conf_mat = np.array(conf_mat)
index = ['fall','normal']
columns = ['fall','normal']
df = pd.DataFrame(conf_mat, index = index, columns = columns)
fig, ax = plt.subplots(1, figsize=(3,3))
sns.heatmap(df, annot=True, square=True, cmap='Blues', fmt="d")
plt.xlabel('prediction')
plt.ylabel('ground_truth')
fig.show()
# Out:
# ['model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001']
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
precision = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[1,0]))
recall = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[0,1]))
print("Precision =", precision, "Recall =", recall)
# Out:
# ('Precision =', 0.952054794520548, 'Recall =', 0.6525821596244131)

# %% [markdown]
# ### Source Test

# %%
conf_mat, _ = get_confusion_matrix(M, saver, src.test, restore_names, iteration=Iter)
conf_mat = np.array(conf_mat)
index = ['fall','normal']
columns = ['fall','normal']
df = pd.DataFrame(conf_mat, index = index, columns = columns)
fig, ax = plt.subplots(1, figsize=(3,3))
sns.heatmap(df, annot=True, square=True, cmap='Blues', fmt="d")
plt.xlabel('prediction')
plt.ylabel('ground_truth')
fig.show()
# Out:
# ['model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001']
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000

# %%
precision = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[1,0]))
recall = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[0,1]))
print("Precision =", precision, "Recall =", recall)
# Out:
# ('Precision =', 0.6829268292682927, 'Recall =', 0.36129032258064514)

# %% [markdown]
# ### Target Train

# %%
conf_mat, prediction_vada = get_confusion_matrix(M, saver, trg.train, restore_names, iteration=Iter)
conf_mat = np.array(conf_mat)
index = ['fall','normal']
columns = ['fall','normal']
df = pd.DataFrame(conf_mat, index = index, columns = columns)
fig, ax = plt.subplots(1, figsize=(3,3))
sns.heatmap(df, annot=True, square=True, cmap='Blues', fmt="d")
plt.xlabel('prediction')
plt.ylabel('ground_truth')
fig.show()
# Out:
# ['model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001']
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000

# %%
precision = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[1,0]))
recall = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[0,1]))
print("Precision =", precision, "Recall =", recall)
# Out:
# ('Precision =', 0.762962962962963, 'Recall =', 0.8512396694214877)

# %% [markdown]
# ### Target Test

# %%
conf_mat, prediction_vada = get_confusion_matrix(M, saver, trg.test, restore_names, iteration=Iter)
conf_mat = np.array(conf_mat)
index = ['fall','normal']
columns = ['fall','normal']
df = pd.DataFrame(conf_mat, index = index, columns = columns)
fig, ax = plt.subplots(1, figsize=(3,3))
sns.heatmap(df, annot=True, square=True, cmap='Blues', fmt="d")
plt.xlabel('prediction')
plt.ylabel('ground_truth')
fig.show()
# Out:
# ['model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001']
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000

# %%
precision = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[1,0]))
recall = (float(conf_mat[0,0]) / (conf_mat[0,0] + conf_mat[0,1]))
print("Precision =", precision, "Recall =", recall)
# Out:
# ('Precision =', 1.0, 'Recall =', 0.9487179487179487)

# %%
acc = get_accuracy(M, saver, src, restore_names, iteration=Iter)
acc = get_accuracy(M, saver, trg, restore_names, iteration=Iter)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# [0.96099997758865352, 0.92447130233499586]
# INFO:tensorflow:Restoring parameters from checkpoints/model=dann_embed_src=wifistanford_trg=wifimexico_design=conv_1d_trim=4_dw=1e-02_sbw=1e+00_cw=1e-02_tbw=1e-02_dirt=00000_init=0_pivot=90000_up=0_uval=0e+00_dn=0_dcval=0e+00_dwdn=0_phase=0_run=0001/model-80000
# [0.95299998521804818, 0.99413486799536566]
